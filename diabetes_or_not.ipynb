# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
x = df.drop(columns=['Outcome'])
y = df['Outcome']

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
import tensorflow as tf
from tensorflow.keras import models,layers
from tensorflow.keras.optimizers import SGD

# %%
model = models.Sequential()
model.add(layers.Dense(128,activation='relu',input_shape=(x_train.shape[1],)))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(32,activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))

model.compile(optimizer = 'SGD',loss = 'binary_crossentropy',metrics= ['accuracy'])
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(x_train,y_train,batch_size=64,epochs=20)
# Out:
# Epoch 1/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4053 - loss: 0.7161
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3636 - loss: 0.7165
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4187 - loss: 0.7032
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4617 - loss: 0.6965
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6297 - loss: 0.6888
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6597 - loss: 0.6803
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6822 - loss: 0.6755
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6966 - loss: 0.6660
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6935 - loss: 0.6627
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6942 - loss: 0.6588
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6949 - loss: 0.6539
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7111 - loss: 0.6489
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6773 - loss: 0.6476
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6874 - loss: 0.6413
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7052 - loss: 0.6378
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6788 - loss: 0.6396
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7023 - loss: 0.6322
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6984 - loss: 0.6263
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6999 - loss: 0.6220
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6988 - loss: 0.6224

# %%
test_accuracy,test_loss=model.evaluate(x_test,y_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7467 - loss: 0.6004

# %%
print(test_accuracy,test_loss)
# Out:
# 0.6013626456260681 0.7467532753944397

# %%
predications = model.predict(x_test)
print(predications)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step
# [[0.40845767]
#  [0.40407366]
#  [0.41782993]
#  [0.44562858]
#  [0.49601167]
#  [0.4202564 ]
#  [0.3697312 ]
#  [0.45968333]
#  [0.55091554]
#  [0.46630207]
#  [0.4989602 ]
#  [0.43633035]
#  [0.42734987]
#  [0.47599766]
#  [0.3950203 ]
#  [0.40584725]
#  [0.4276341 ]
#  [0.41742417]
#  [0.37098223]
#  [0.47330922]
#  [0.4201371 ]
#  [0.46320403]
#  [0.433821  ]
#  [0.3903615 ]
#  [0.49329042]
#  [0.39863497]
#  [0.47304982]
#  [0.44197124]
#  [0.4735859 ]
#  [0.4014108 ]
#  [0.40193307]
#  [0.44425103]
#  [0.42772892]
#  [0.39493635]
#  [0.41355273]
#  [0.48468667]
#  [0.4817278 ]
#  [0.37519398]
#  [0.3940707 ]
#  [0.47209424]
#  [0.37667385]
#  [0.42862028]
#  [0.45141378]
#  [0.524948  ]
#  [0.38617086]
#  [0.36533484]
#  [0.54113156]
#  [0.5029744 ]
#  [0.37836343]
#  [0.5750301 ]
#  [0.44836536]
#  [0.47037122]
#  [0.43082657]
#  [0.39676642]
#  [0.3808112 ]
#  [0.5084528 ]
#  [0.47392246]
#  [0.49823776]
#  [0.44579107]
#  [0.40051976]
#  [0.4287458 ]
#  [0.47308564]
#  [0.47379166]
#  [0.49874908]
#  [0.49066514]
#  [0.46940216]
#  [0.3890677 ]
#  [0.42220435]
#  [0.54595554]
#  [0.44008163]
#  [0.4506764 ]
#  [0.35532826]
#  [0.486264  ]
#  [0.4008763 ]
#  [0.46461836]
#  [0.54790044]
#  [0.38420814]
#  [0.5380453 ]
#  [0.535568  ]
#  [0.47207987]
#  [0.5001568 ]
#  [0.37166426]
#  [0.36695126]
#  [0.37081718]
#  [0.4413649 ]
#  [0.49827236]
#  [0.4471683 ]
#  [0.4588219 ]
#  [0.46921113]
#  [0.4758965 ]
#  [0.41556996]
#  [0.46841374]
#  [0.4108102 ]
#  [0.43690848]
#  [0.53635955]
#  [0.3990585 ]
#  [0.43021172]
#  [0.41315082]
#  [0.47744477]
#  [0.43577757]
#  [0.49440864]
#  [0.44363844]
#  [0.3982345 ]
#  [0.45124474]
#  [0.4010747 ]
#  [0.42212343]
#  [0.39352566]
#  [0.40252766]
#  [0.48504898]
#  [0.44127595]
#  [0.42981756]
#  [0.38572687]
#  [0.32762805]
#  [0.4797399 ]
#  [0.3738349 ]
#  [0.35936219]
#  [0.3838948 ]
#  [0.37272882]
#  [0.4392723 ]
#  [0.3886619 ]
#  [0.38545775]
#  [0.5101936 ]
#  [0.5763806 ]
#  [0.40957716]
#  [0.4922957 ]
#  [0.4852746 ]
#  [0.50490844]
#  [0.42630205]
#  [0.5250626 ]
#  [0.43812013]
#  [0.435145  ]
#  [0.42274785]
#  [0.39207244]
#  [0.40043157]
#  [0.40336332]
#  [0.451758  ]
#  [0.41379595]
#  [0.39697137]
#  [0.43673003]
#  [0.49201766]
#  [0.42627737]
#  [0.42475942]
#  [0.5359055 ]
#  [0.42658734]
#  [0.3761941 ]
#  [0.38483188]
#  [0.49847752]
#  [0.40856135]
#  [0.3769731 ]
#  [0.44479117]
#  [0.50207746]
#  [0.44461852]
#  [0.38462275]
#  [0.387435  ]]

# %%
n = 10
for i in range(n):
    if predications[i]>0.5:
        print("Diabetic")
    else:
        print("not Diabetic")
    print(f"Prediction {i+1}: {predications[i]}\n")
# Out:
# not Diabetic
# Prediction 1: [0.40845767]
#
# not Diabetic
# Prediction 2: [0.40407366]
#
# not Diabetic
# Prediction 3: [0.41782993]
#
# not Diabetic
# Prediction 4: [0.44562858]
#
# not Diabetic
# Prediction 5: [0.49601167]
#
# not Diabetic
# Prediction 6: [0.4202564]
#
# not Diabetic
# Prediction 7: [0.3697312]
#
# not Diabetic
# Prediction 8: [0.45968333]
#
# Diabetic
# Prediction 9: [0.55091554]
#
# not Diabetic
# Prediction 10: [0.46630207]
